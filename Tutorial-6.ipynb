# %% [markdown]
# # Tutorial 6: Reverse-Mapping Paths to Atomistic Structures
# ### Learning Objectives
# * Determining bead size for building paths
# * Apply a reverse map
# * Reverse map crosslinked structures
# * Relaxing a box
# ### Key Points
# * TODO all code here

# %% [markdown]
# ## Setup
# ------

# %%
# Import necessary libraries
import mbuild as mb
from mbuild.polymer import Polymer

# Check mBuild version
print(f"mBuild version: {mb.__version__}")
# Out:
# mBuild version: 1.3.1

# %% [markdown]
# ## Use forcefield/monomer to determine bead size and bond length
# -----

# %%
# Print forcefield

# Load monomer and get bounding box

# %% [markdown]
# ## Reverse map
# --------

# %%
# Build a random-walk

# Load monomer

# apply reverse map

# visualize

# %% [markdown]
# ## Crosslinked reverse map
# -----

# %%
# Create crosslinked structure

# load crosslinker and backbond

# apply

# %% [markdown]
# ## Relax structures
# -----

# %%
# breakable bonds???

# %% [markdown]
# ### Exercise:
